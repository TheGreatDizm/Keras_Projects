# %%
from tensorflow import keras
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau


def data_loading(data_dir, target_size=(256, 256), batch_size=32, validation_split=0.2):
    datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=0.15,
        vertical_flip=0.15,
        validation_split=validation_split
    )

    train_generator = datagen.flow_from_directory(
        data_dir,
        target_size=target_size,
        color_mode="rgb",
        batch_size=batch_size,
        class_mode="categorical",
        subset='training'
    )

    val_generator = datagen.flow_from_directory(
        data_dir,
        target_size=target_size,
        color_mode="rgb",
        batch_size=batch_size,
        class_mode="categorical",
        subset='validation'
    )

    return train_generator, val_generator


def model(input_shape, num_classes):
    base_model = Xception(
        include_top=False,
        input_shape=input_shape,
        pooling="avg"
    )
    x = base_model.output
    x = Flatten()(x)
    x = Dense(256, activation="relu")(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation="softmax")(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(
        loss="categorical_crossentropy",
        optimizer="adam",
        metrics=["accuracy"]
    )

    return model


def training(model, train_generator, val_generator, log_folder):
    checkpoint = ModelCheckpoint(
        os.path.join(log_folder, 'best_model.h5'),
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    )
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    )
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=3,
        verbose=1
    )
    tensorboard_callback = TensorBoard(
        log_dir=log_folder,
        histogram_freq=1
    )

    history = model.fit(
        train_generator,
        epochs=25,
        validation_data=val_generator,
        callbacks=[checkpoint, early_stopping, reduce_lr, tensorboard_callback]
    )

    return history


def evaluation(model, val_generator):
    test_loss, test_acc = model.evaluate(val_generator)
    print("Test accuracy: {:.2%}".format(test_acc))

    test_preds = model.predict(val_generator)
    test_labels = np.argmax(test_preds, axis=-1)

    conf_mat = confusion_matrix(test_labels, val_generator.classes)
    print(conf_mat)
    # Plot the training and validation accuracy and loss
    acc_plt=(plt.figure(figsize=(8, 6)),
    plt.subplot(1, 2, 1),
    plt.plot(history.history['accuracy'], label='Training Accuracy'),
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy'),
    plt.legend(),
    plt.title('Accuracy'))

    los_plt=(plt.subplot(1, 2, 2),
    plt.plot(history.history['loss'], label='Training Loss'),
    plt.plot(history.history['val_loss'], label='Validation Loss'),
    plt.legend(),
    plt.title('Loss'),
    plt.show())

if __name__ == "__main__":
    # Load the dataset
    data_dir = "/content/drive/MyDrive/train"

    # Define the number of classes
    num_classes = 3

    # Load and split the data
    train_generator, val_generator = data_loading(data_dir)

    # Build the model
    input_shape = (256, 256, 3)
    model = model(input_shape, num_classes)

    # Define the log folder for callbacks
    log_folder = 'logs'

    # Train the model
    history = training(model, train_generator, val_generator, log_folder)

    # Evaluate the model
    evaluation(model, val_generator)

    # Save the trained model
    model.save("/content/drive/MyDrive/trained_model.hdf5")
# Out:
# Found 935 images belonging to 3 classes.
# Found 232 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 2s 0us/step
# Epoch 1/25
# 30/30 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.7690
# Epoch 1: val_loss improved from inf to 6.89784, saving model to logs/best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 30/30 [==============================] - 437s 13s/step - loss: 0.6010 - accuracy: 0.7690 - val_loss: 6.8978 - val_accuracy: 0.6207 - lr: 0.0010
# Epoch 2/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.9187
# Epoch 2: val_loss improved from 6.89784 to 4.88844, saving model to logs/best_model.h5
# 30/30 [==============================] - 41s 1s/step - loss: 0.2591 - accuracy: 0.9187 - val_loss: 4.8884 - val_accuracy: 0.7457 - lr: 0.0010
# Epoch 3/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9433
# Epoch 3: val_loss improved from 4.88844 to 2.34748, saving model to logs/best_model.h5
# 30/30 [==============================] - 45s 2s/step - loss: 0.1659 - accuracy: 0.9433 - val_loss: 2.3475 - val_accuracy: 0.6940 - lr: 0.0010
# Epoch 4/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9636
# Epoch 4: val_loss improved from 2.34748 to 1.34700, saving model to logs/best_model.h5
# 30/30 [==============================] - 40s 1s/step - loss: 0.1403 - accuracy: 0.9636 - val_loss: 1.3470 - val_accuracy: 0.8362 - lr: 0.0010
# Epoch 5/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1866 - accuracy: 0.9476
# Epoch 5: val_loss did not improve from 1.34700
# 30/30 [==============================] - 40s 1s/step - loss: 0.1866 - accuracy: 0.9476 - val_loss: 4.8558 - val_accuracy: 0.5991 - lr: 0.0010
# Epoch 6/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9187
# Epoch 6: val_loss improved from 1.34700 to 1.26693, saving model to logs/best_model.h5
# 30/30 [==============================] - 42s 1s/step - loss: 0.2367 - accuracy: 0.9187 - val_loss: 1.2669 - val_accuracy: 0.8707 - lr: 0.0010
# Epoch 7/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9626
# Epoch 7: val_loss did not improve from 1.26693
# 30/30 [==============================] - 40s 1s/step - loss: 0.1977 - accuracy: 0.9626 - val_loss: 2.7251 - val_accuracy: 0.7241 - lr: 0.0010
# Epoch 8/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.9037
# Epoch 8: val_loss did not improve from 1.26693
# 30/30 [==============================] - 44s 1s/step - loss: 0.2901 - accuracy: 0.9037 - val_loss: 4.5589 - val_accuracy: 0.6595 - lr: 0.0010
# Epoch 9/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9583
# Epoch 9: val_loss did not improve from 1.26693
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 [==============================] - 41s 1s/step - loss: 0.1124 - accuracy: 0.9583 - val_loss: 1.4551 - val_accuracy: 0.9052 - lr: 0.0010
# Epoch 10/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9626
# Epoch 10: val_loss improved from 1.26693 to 0.20724, saving model to logs/best_model.h5
# 30/30 [==============================] - 49s 2s/step - loss: 0.1434 - accuracy: 0.9626 - val_loss: 0.2072 - val_accuracy: 0.9569 - lr: 1.0000e-04
# Epoch 11/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9850
# Epoch 11: val_loss improved from 0.20724 to 0.16124, saving model to logs/best_model.h5
# 30/30 [==============================] - 44s 1s/step - loss: 0.0531 - accuracy: 0.9850 - val_loss: 0.1612 - val_accuracy: 0.9569 - lr: 1.0000e-04
# Epoch 12/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9829
# Epoch 12: val_loss did not improve from 0.16124
# 30/30 [==============================] - 40s 1s/step - loss: 0.0520 - accuracy: 0.9829 - val_loss: 0.1790 - val_accuracy: 0.9612 - lr: 1.0000e-04
# Epoch 13/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9904
# Epoch 13: val_loss did not improve from 0.16124
# 30/30 [==============================] - 45s 1s/step - loss: 0.0436 - accuracy: 0.9904 - val_loss: 0.1825 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 14/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9872
# Epoch 14: val_loss did not improve from 0.16124
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 30/30 [==============================] - 39s 1s/step - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.2016 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 15/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9829
# Epoch 15: val_loss improved from 0.16124 to 0.13694, saving model to logs/best_model.h5
# 30/30 [==============================] - 46s 2s/step - loss: 0.0533 - accuracy: 0.9829 - val_loss: 0.1369 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 16/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9807
# Epoch 16: val_loss did not improve from 0.13694
# 30/30 [==============================] - 39s 1s/step - loss: 0.0679 - accuracy: 0.9807 - val_loss: 0.1736 - val_accuracy: 0.9698 - lr: 1.0000e-05
# Epoch 17/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9829
# Epoch 17: val_loss did not improve from 0.13694
# 30/30 [==============================] - 44s 1s/step - loss: 0.0568 - accuracy: 0.9829 - val_loss: 0.1576 - val_accuracy: 0.9569 - lr: 1.0000e-05
# Epoch 18/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9872
# Epoch 18: val_loss did not improve from 0.13694
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 30/30 [==============================] - 41s 1s/step - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.1474 - val_accuracy: 0.9612 - lr: 1.0000e-05
# Epoch 19/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9882
# Epoch 19: val_loss improved from 0.13694 to 0.10405, saving model to logs/best_model.h5
# 30/30 [==============================] - 48s 2s/step - loss: 0.0389 - accuracy: 0.9882 - val_loss: 0.1040 - val_accuracy: 0.9698 - lr: 1.0000e-06
# Epoch 20/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9882
# Epoch 20: val_loss did not improve from 0.10405
# 30/30 [==============================] - 41s 1s/step - loss: 0.0368 - accuracy: 0.9882 - val_loss: 0.1124 - val_accuracy: 0.9612 - lr: 1.0000e-06
# Epoch 21/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9840
# Epoch 21: val_loss improved from 0.10405 to 0.09632, saving model to logs/best_model.h5
# 30/30 [==============================] - 45s 1s/step - loss: 0.0465 - accuracy: 0.9840 - val_loss: 0.0963 - val_accuracy: 0.9612 - lr: 1.0000e-06
# Epoch 22/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9872
# Epoch 22: val_loss did not improve from 0.09632
# 30/30 [==============================] - 41s 1s/step - loss: 0.0538 - accuracy: 0.9872 - val_loss: 0.1177 - val_accuracy: 0.9612 - lr: 1.0000e-06
# Epoch 23/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9829
# Epoch 23: val_loss did not improve from 0.09632
# 30/30 [==============================] - 44s 1s/step - loss: 0.0586 - accuracy: 0.9829 - val_loss: 0.1367 - val_accuracy: 0.9569 - lr: 1.0000e-06
# Epoch 24/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9850
# Epoch 24: val_loss did not improve from 0.09632
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 30/30 [==============================] - 40s 1s/step - loss: 0.0537 - accuracy: 0.9850 - val_loss: 0.0984 - val_accuracy: 0.9526 - lr: 1.0000e-06
# Epoch 25/25
# 30/30 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9807
# Epoch 25: val_loss did not improve from 0.09632
# 30/30 [==============================] - 43s 1s/step - loss: 0.0464 - accuracy: 0.9807 - val_loss: 0.1161 - val_accuracy: 0.9655 - lr: 1.0000e-07
# 8/8 [==============================] - 7s 851ms/step - loss: 0.1139 - accuracy: 0.9526
# Test accuracy: 95.26%
# 8/8 [==============================] - 6s 575ms/step
# [[29 30 18]
#  [17 32 27]
#  [31 16 32]]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
